# %%
## creating a dictonaries
empty_dict = {}
print(type(empty_dict))
# Out:
# <class 'dict'>

# %%
empty_dict = dict()
empty_dict
# Out:
# {}

# %%
student={'name':'John', 'age':25, 'courses':['Math','CompSci']}
print(student)
print(student['name'])
# Out:
# {'name': 'John', 'age': 25, 'courses': ['Math', 'CompSci']}
# John

# %%
#Single key is always used
student={'name':'John', 'name':25, 'courses':['Math','CompSci']}
print(student)
# Out:
# {'name': 25, 'courses': ['Math', 'CompSci']}

# %%
#acessing Dicatonaries elements
student={'name':'John', 'age':25, 'courses':['Math','CompSci']}
print(student['courses'])
print(student.get('age'))

#Acessing using get method 
print(student.get('name'))
print(student.get('phone'))  #returns None if key not found
print(student.get('phone','Not Found'))  #returns Not Found if key not found
# Out:
# ['Math', 'CompSci']
# 25
# John
# None
# Not Found

# %%
## Modifying Dictionaries elenments they are mutable
student={'name':'John', 'age':25, 'courses':['Math','CompSci']}
student['age']=26
student['phone']='555-5555' #adding new key value pair
print(student)
# Out:
# {'name': 'John', 'age': 26, 'courses': ['Math', 'CompSci'], 'phone': '555-5555'}

# %%
del student['courses']  #deleting key value pair
print(student)
# Out:
# {'name': 'John', 'age': 26, 'phone': '555-5555'}

# %%
## Dictionary Methods
student={'name':'John', 'age':25, 'courses':['Math','CompSci']}
print(student.keys()) ## prints all keys
print(student.values()) ## prints all values
print(student.items()) ## prints all key value pairs
# Out:
# dict_keys(['name', 'age', 'courses'])
# dict_values(['John', 25, ['Math', 'CompSci']])
# dict_items([('name', 'John'), ('age', 25), ('courses', ['Math', 'CompSci'])])

# %%
## shallow copy
student_copy=student
print(student)
print(student_copy)
# Out:
# {'name': 'John', 'age': 25, 'courses': ['Math', 'CompSci']}
# {'name': 'John', 'age': 25, 'courses': ['Math', 'CompSci']}

# %%
student["name"] = "Jane"
print(student)
print(student_copy)
# Out:
# {'name': 'Jane', 'age': 25, 'courses': ['Math', 'CompSci']}
# {'name': 'Jane', 'age': 25, 'courses': ['Math', 'CompSci']}

# %%
student_copy1=student.copy()  #deep copy
print(student)
print(student_copy1)
# Out:
# {'name': 'Jane', 'age': 25, 'courses': ['Math', 'CompSci']}
# {'name': 'Jane', 'age': 25, 'courses': ['Math', 'CompSci']}

# %%
student["name"]="Tony"
print(student)
print(student_copy1)
# Out:
# {'name': 'Tony', 'age': 25, 'courses': ['Math', 'CompSci']}
# {'name': 'Jane', 'age': 25, 'courses': ['Math', 'CompSci']}

# %%
## Iterating through dictionaries
student={'name':'John', 'age':25, 'courses':['Math','CompSci']}
for key in student:
    print(key,student[key])
# Out:
# name John
# age 25
# courses ['Math', 'CompSci']

# %%
for keys in student.keys():
    print(keys)
# Out:
# name
# age
# courses

# %%
for keys in student.values():
    print(keys)
# Out:
# John
# 25
# ['Math', 'CompSci']

# %%
f

# %%
for key,value in student.items():
    print(key,value)
# Out:
# name John
# age 25
# courses ['Math', 'CompSci']

# %%
## Nested Dictionaries
students={
    'student1':{'name':'John', 'age':25, 'courses':['Math','CompSci']},
    'student2':{'name':'Jane', 'age':22, 'courses':['Eng','Hist']}
}
print(students['student1'])
print(students['student1']['courses'])
print(students['student2']['age'])
# Out:
# {'name': 'John', 'age': 25, 'courses': ['Math', 'CompSci']}
# ['Math', 'CompSci']
# 22

# %%
## Iterating through nested dictionaries
for student_id, student_info in students.items():
    print(student_id)
    for key, value in student_info.items():
        print(f"  {key}: {value}")
# Out:
# student1
#   name: John
#   age: 25
#   courses: ['Math', 'CompSci']
# student2
#   name: Jane
#   age: 22
#   courses: ['Eng', 'Hist']

# %%
## Dictionary Comphrension
squares={x:x**2 for x in range(6)}
print(squares)
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
## condition dictionary comprehension
even_squares={x:x**2 for x in range(6) if x%2==0}
print(even_squares)
# Out:
# {0: 0, 2: 4, 4: 16}

# %%
## Practical Example

numbers=[1,2,2,2,3,3,3,4,4,4,4]
frequency={}
for number in numbers:
    if number in frequency:
        frequency[number]+=1
    else:
        frequency[number]=1
print(frequency)
# Out:
# {1: 1, 2: 3, 3: 3, 4: 4}

# %%
## Merge two dictionaries
dict1={'a':1, 'b':2}
dict2={'b':3, 'c':4}
dict1.update(dict2)
print(dict1)
merged_dict={**dict1, **dict2}
print(merged_dict)
# Out:
# {'a': 1, 'b': 3, 'c': 4}
# {'a': 1, 'b': 3, 'c': 4}
